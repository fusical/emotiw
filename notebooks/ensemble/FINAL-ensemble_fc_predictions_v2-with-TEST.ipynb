# %% [markdown]
# <a href="https://colab.research.google.com/github/kevincong95/cs231n-emotiw/blob/master/notebooks/2.4-tj-la-ak-kc-vl-FINAL-ensemble_fc_predictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Video Sentiment Analysis in the Wild
# Ensembling Notebook | FC | CS231n
#
# ### Modalities Used
# - Scene (VGG - single LSTM head) [model](https://storage.googleapis.com/cs231n-emotiw/models/vgg19-lstm-cp-0003.h5)
# - Pose [model](https://storage.googleapis.com/cs231n-emotiw/models/pose-classifier-64lstm-0.01reg.h5)
# - Audio [model](https://storage.googleapis.com/cs231n-emotiw/models/openl3-cnn-lstm-tuned-lr.h5)
# - Image Captioning [model](https://storage.googleapis.com/cs231n-emotiw/models/sentiment-transformer_sentiment-transformer_756.pth) and [model metadata](https://storage.googleapis.com/cs231n-emotiw/models/sentiment-transformer-16.metadata.bin)
#
# Test Accuracy = **59.9%**
#
# FC Model: https://storage.googleapis.com/cs231n-emotiw/models/ensemble-fc-final-v2.h5

# %% [markdown]
# ### Copy Pre-Processed Files

# %%
# !ls
# Out:
# sample_data

# %%
# !nvidia-smi
# Out:
# Wed Jun 24 05:19:21 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# FULL_PATH = 'My Drive/Machine-Learning-Projects/cs231n-project/datasets/emotiw'
FULL_PATH = 'My Drive/cs231n-project/datasets/emotiw'
# !cp /content/drive/'$FULL_PATH'/test-final-* .
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/drive/'My Drive'/cs231n-project/datasets/emotiw/Test_labels.txt .

# %%
# !ls
# Out:
# drive	     test-final-audio.zip  test-final-fer.zip	  test-final-pose.zip
# sample_data  test-final-faces.zip  test-final-frames.zip  Test_labels.txt

# %%
# RUN THIS FOR FINAL FILES (zip includes root folder)

# !unzip -d test-final-audio test-final-audio.zip
# !unzip -d test-final-faces test-final-faces.zip
# !unzip -d test-final-frames test-final-frames.zip
# !unzip -d test-final-pose test-final-pose.zip
# !unzip -d test-final-fer test-final-fer.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test-final-pose/3/frame_Test_55.mp4_9_keypoints.json
#   inflating: test-final-pose/3/frame_Test_337.mp4_14_keypoints.json
#   inflating: test-final-pose/3/frame_Test_275.mp4_9_keypoints.json
#   inflating: test-final-pose/3/frame_Test_310.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_271.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_132.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_320.mp4_7_keypoints.json
#   inflating: test-final-pose/3/frame_Test_244.mp4_14_keypoints.json
#   inflating: test-final-pose/3/frame_Test_5.mp4_8_keypoints.json
#   inflating: test-final-pose/3/frame_Test_94.mp4_14_keypoints.json
#   inflating: test-final-pose/3/frame_Test_180.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_183.mp4_13_keypoints.json
#   inflating: test-final-pose/3/frame_Test_448.mp4_5_keypoints.json
#   inflating: test-final-pose/3/frame_Test_392.mp4_5_keypoints.json
#   inflating: test-final-pose/3/frame_Test_136.mp4_5_keypoints.json
#   inflating: test-final-pose/3/frame_Test_411.mp4_6_keypoints.json
#   inflating: test-final-pose/3/frame_Test_554.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_376.mp4_1_keypoints.json
#   inflating: test-final-pose/3/frame_Test_366.mp4_13_keypoints.json
#   inflating: test-final-pose/3/frame_Test_72.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_521.mp4_1_keypoints.json
#   inflating: test-final-pose/3/frame_Test_321.mp4_1_keypoints.json
#   inflating: test-final-pose/3/frame_Test_29.mp4_5_keypoints.json
#   inflating: test-final-pose/3/frame_Test_692.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_132.mp4_0_keypoints.json
#   inflating: test-final-pose/3/frame_Test_554.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_281.mp4_10_keypoints.json
#   inflating: test-final-pose/3/frame_Test_337.mp4_4_keypoints.json
#   inflating: test-final-pose/3/frame_Test_99.mp4_9_keypoints.json
#   inflating: test-final-pose/3/frame_Test_32.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_318.mp4_6_keypoints.json
#   inflating: test-final-pose/3/frame_Test_398.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_42.mp4_4_keypoints.json
#   inflating: test-final-pose/3/frame_Test_272.mp4_1_keypoints.json
#   inflating: test-final-pose/3/frame_Test_673.mp4_5_keypoints.json
#   inflating: test-final-pose/3/frame_Test_495.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_476.mp4_8_keypoints.json
#   inflating: test-final-pose/3/frame_Test_337.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_171.mp4_11_keypoints.json
#   inflating: test-final-pose/3/frame_Test_697.mp4_10_keypoints.json
#   inflating: test-final-pose/3/frame_Test_272.mp4_5_keypoints.json
#   inflating: test-final-pose/3/frame_Test_370.mp4_1_keypoints.json
#   inflating: test-final-pose/3/frame_Test_714.mp4_6_keypoints.json
#   inflating: test-final-pose/3/frame_Test_585.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_281.mp4_12_keypoints.json
#   inflating: test-final-pose/3/frame_Test_321.mp4_6_keypoints.json
#   inflating: test-final-pose/3/frame_Test_369.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_660.mp4_10_keypoints.json
#   inflating: test-final-pose/3/frame_Test_477.mp4_10_keypoints.json
#   inflating: test-final-pose/3/frame_Test_684.mp4_8_keypoints.json
#   inflating: test-final-pose/3/frame_Test_612.mp4_9_keypoints.json
#   inflating: test-final-pose/3/frame_Test_12.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_209.mp4_7_keypoints.json
#   inflating: test-final-pose/3/frame_Test_472.mp4_7_keypoints.json
#   inflating: test-final-pose/3/frame_Test_90.mp4_0_keypoints.json
#   inflating: test-final-pose/3/frame_Test_25.mp4_9_keypoints.json
#   inflating: test-final-pose/3/frame_Test_579.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_749.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_318.mp4_7_keypoints.json
#   inflating: test-final-pose/3/frame_Test_708.mp4_8_keypoints.json
#   inflating: test-final-pose/3/frame_Test_172.mp4_4_keypoints.json
#   inflating: test-final-pose/3/frame_Test_165.mp4_0_keypoints.json
#   inflating: test-final-pose/3/frame_Test_681.mp4_9_keypoints.json
#   inflating: test-final-pose/3/frame_Test_444.mp4_6_keypoints.json
#   inflating: test-final-pose/3/frame_Test_254.mp4_13_keypoints.json
#   inflating: test-final-pose/3/frame_Test_752.mp4_7_keypoints.json
#   inflating: test-final-pose/3/frame_Test_318.mp4_14_keypoints.json
#   inflating: test-final-pose/3/frame_Test_166.mp4_7_keypoints.json
#   inflating: test-final-pose/3/frame_Test_268.mp4_4_keypoints.json
#   inflating: test-final-pose/3/frame_Test_673.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_632.mp4_9_keypoints.json
#   inflating: test-final-pose/3/frame_Test_32.mp4_8_keypoints.json
#   inflating: test-final-pose/3/frame_Test_666.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_626.mp4_5_keypoints.json
#   inflating: test-final-pose/3/frame_Test_5.mp4_14_keypoints.json
#   inflating: test-final-pose/3/frame_Test_120.mp4_10_keypoints.json
#   inflating: test-final-pose/3/frame_Test_67.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_12.mp4_8_keypoints.json
#   inflating: test-final-pose/3/frame_Test_684.mp4_10_keypoints.json
#   inflating: test-final-pose/3/frame_Test_443.mp4_11_keypoints.json
#   inflating: test-final-pose/3/frame_Test_461.mp4_10_keypoints.json
#   inflating: test-final-pose/3/frame_Test_12.mp4_10_keypoints.json
#   inflating: test-final-pose/3/frame_Test_86.mp4_5_keypoints.json
#   inflating: test-final-pose/3/frame_Test_652.mp4_5_keypoints.json
#   inflating: test-final-pose/3/frame_Test_251.mp4_0_keypoints.json
#   inflating: test-final-pose/3/frame_Test_321.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_681.mp4_6_keypoints.json
#   inflating: test-final-pose/3/frame_Test_271.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_154.mp4_4_keypoints.json
#   inflating: test-final-pose/3/frame_Test_194.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_392.mp4_7_keypoints.json
#   inflating: test-final-pose/3/frame_Test_302.mp4_9_keypoints.json
#   inflating: test-final-pose/3/frame_Test_83.mp4_12_keypoints.json
#   inflating: test-final-pose/3/frame_Test_614.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_412.mp4_6_keypoints.json
#   inflating: test-final-pose/3/frame_Test_741.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_42.mp4_1_keypoints.json
#   inflating: test-final-pose/3/frame_Test_486.mp4_11_keypoints.json
#   inflating: test-final-pose/3/frame_Test_132.mp4_1_keypoints.json
#   inflating: test-final-pose/3/frame_Test_243.mp4_6_keypoints.json
#   inflating: test-final-pose/3/frame_Test_623.mp4_4_keypoints.json
#   inflating: test-final-pose/3/frame_Test_398.mp4_8_keypoints.json
#   inflating: test-final-pose/3/frame_Test_412.mp4_14_keypoints.json
#   inflating: test-final-pose/3/frame_Test_646.mp4_13_keypoints.json
#   inflating: test-final-pose/3/frame_Test_61.mp4_11_keypoints.json
#   inflating: test-final-pose/3/frame_Test_124.mp4_6_keypoints.json
#   inflating: test-final-pose/3/frame_Test_470.mp4_8_keypoints.json
#   inflating: test-final-pose/3/frame_Test_440.mp4_12_keypoints.json
#   inflating: test-final-pose/3/frame_Test_57.mp4_12_keypoints.json
#   inflating: test-final-pose/3/frame_Test_708.mp4_6_keypoints.json
#   inflating: test-final-pose/3/frame_Test_470.mp4_14_keypoints.json
#   inflating: test-final-pose/3/frame_Test_486.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_78.mp4_4_keypoints.json
#   inflating: test-final-pose/3/frame_Test_22.mp4_4_keypoints.json
#   inflating: test-final-pose/3/frame_Test_634.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_612.mp4_4_keypoints.json
#   inflating: test-final-pose/3/frame_Test_552.mp4_5_keypoints.json
#   inflating: test-final-pose/3/frame_Test_268.mp4_9_keypoints.json
#   inflating: test-final-pose/3/frame_Test_454.mp4_8_keypoints.json
#   inflating: test-final-pose/3/frame_Test_570.mp4_7_keypoints.json
#   inflating: test-final-pose/3/frame_Test_196.mp4_7_keypoints.json
#   inflating: test-final-pose/3/frame_Test_124.mp4_14_keypoints.json
#   inflating: test-final-pose/3/frame_Test_194.mp4_1_keypoints.json
#   inflating: test-final-pose/3/frame_Test_194.mp4_7_keypoints.json
#   inflating: test-final-pose/3/frame_Test_270.mp4_11_keypoints.json
#   inflating: test-final-pose/3/frame_Test_584.mp4_9_keypoints.json
#   inflating: test-final-pose/3/frame_Test_532.mp4_2_keypoints.json
#   inflating: test-final-pose/3/frame_Test_559.mp4_3_keypoints.json
#   inflating: test-final-pose/3/frame_Test_22.mp4_11_keypoints.json
#   inflating: test-final-pose/3/frame_Test_75.mp4_13_keypoints.json
#   inflating: test-final-pose/3/frame_Test_421.mp4_6_keypoints.json
#   inflating: test-final-pose/3/frame_Test_61.mp4_1_keypoints.json
#   inflating: test-final-pose/3/frame_Test_661.mp4_7_keypoints.json
#   inflating: test-final-pose/3/frame_Test_120.mp4_12_keypoints.json
#   inflating: test-final-pose/3/frame_Test_578.mp4_13_keypoints.json
#   inflating: test-final-pose/3/frame_Test_741.mp4_4_keypoints.json
#   inflating: test-final-pose/3/frame_Test_48.mp4_1_keypoints.json
#   inflating: test-final-pose/3/frame_Test_565.mp4_12_keypoints.json
#   inflating: test-final-pose/3/frame_Test
mp4_0_keypoints.json
#   inflating: test-final-pose/2/frame_Test_535.mp4_14_keypoints.json
#   inflating: test-final-pose/2/frame_Test_246.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_625.mp4_4_keypoints.json
#   inflating: test-final-pose/2/frame_Test_358.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_691.mp4_12_keypoints.json
#   inflating: test-final-pose/2/frame_Test_340.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_87.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_396.mp4_3_keypoints.json
#   inflating: test-final-pose/2/frame_Test_482.mp4_12_keypoints.json
#   inflating: test-final-pose/2/frame_Test_737.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_303.mp4_1_keypoints.json
#   inflating: test-final-pose/2/frame_Test_31.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_463.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_301.mp4_0_keypoints.json
#   inflating: test-final-pose/2/frame_Test_482.mp4_0_keypoints.json
#   inflating: test-final-pose/2/frame_Test_406.mp4_3_keypoints.json
#   inflating: test-final-pose/2/frame_Test_754.mp4_11_keypoints.json
#   inflating: test-final-pose/2/frame_Test_419.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_719.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_457.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_388.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_446.mp4_9_keypoints.json
#   inflating: test-final-pose/2/frame_Test_602.mp4_14_keypoints.json
#   inflating: test-final-pose/2/frame_Test_492.mp4_1_keypoints.json
#   inflating: test-final-pose/2/frame_Test_672.mp4_9_keypoints.json
#   inflating: test-final-pose/2/frame_Test_671.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_23.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_56.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_176.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_291.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_424.mp4_0_keypoints.json
#   inflating: test-final-pose/2/frame_Test_26.mp4_13_keypoints.json
#   inflating: test-final-pose/2/frame_Test_548.mp4_14_keypoints.json
#   inflating: test-final-pose/2/frame_Test_255.mp4_10_keypoints.json
#   inflating: test-final-pose/2/frame_Test_720.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_190.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_602.mp4_4_keypoints.json
#   inflating: test-final-pose/2/frame_Test_474.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_713.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_135.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_434.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_115.mp4_10_keypoints.json
#   inflating: test-final-pose/2/frame_Test_674.mp4_1_keypoints.json
#   inflating: test-final-pose/2/frame_Test_732.mp4_13_keypoints.json
#   inflating: test-final-pose/2/frame_Test_344.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_485.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_457.mp4_12_keypoints.json
#   inflating: test-final-pose/2/frame_Test_98.mp4_3_keypoints.json
#   inflating: test-final-pose/2/frame_Test_210.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_215.mp4_13_keypoints.json
#   inflating: test-final-pose/2/frame_Test_56.mp4_3_keypoints.json
#   inflating: test-final-pose/2/frame_Test_228.mp4_4_keypoints.json
#   inflating: test-final-pose/2/frame_Test_480.mp4_10_keypoints.json
#   inflating: test-final-pose/2/frame_Test_428.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_479.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_563.mp4_11_keypoints.json
#   inflating: test-final-pose/2/frame_Test_518.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_266.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_184.mp4_11_keypoints.json
#   inflating: test-final-pose/2/frame_Test_378.mp4_10_keypoints.json
#   inflating: test-final-pose/2/frame_Test_356.mp4_12_keypoints.json
#   inflating: test-final-pose/2/frame_Test_71.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_561.mp4_13_keypoints.json
#   inflating: test-final-pose/2/frame_Test_551.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_279.mp4_1_keypoints.json
#   inflating: test-final-pose/2/frame_Test_208.mp4_4_keypoints.json
#   inflating: test-final-pose/2/frame_Test_504.mp4_11_keypoints.json
#   inflating: test-final-pose/2/frame_Test_691.mp4_9_keypoints.json
#   inflating: test-final-pose/2/frame_Test_338.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_144.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_720.mp4_3_keypoints.json
#   inflating: test-final-pose/2/frame_Test_603.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_383.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_463.mp4_11_keypoints.json
#   inflating: test-final-pose/2/frame_Test_356.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_89.mp4_11_keypoints.json
#   inflating: test-final-pose/2/frame_Test_351.mp4_12_keypoints.json
#   inflating: test-final-pose/2/frame_Test_65.mp4_3_keypoints.json
#   inflating: test-final-pose/2/frame_Test_249.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_390.mp4_10_keypoints.json
#   inflating: test-final-pose/2/frame_Test_107.mp4_4_keypoints.json
#   inflating: test-final-pose/2/frame_Test_497.mp4_14_keypoints.json
#   inflating: test-final-pose/2/frame_Test_7.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_127.mp4_1_keypoints.json
#   inflating: test-final-pose/2/frame_Test_62.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_195.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_43.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_291.mp4_14_keypoints.json
#   inflating: test-final-pose/2/frame_Test_336.mp4_1_keypoints.json
#   inflating: test-final-pose/2/frame_Test_214.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_413.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_583.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_435.mp4_13_keypoints.json
#   inflating: test-final-pose/2/frame_Test_349.mp4_11_keypoints.json
#   inflating: test-final-pose/2/frame_Test_687.mp4_1_keypoints.json
#   inflating: test-final-pose/2/frame_Test_343.mp4_0_keypoints.json
#   inflating: test-final-pose/2/frame_Test_378.mp4_9_keypoints.json
#   inflating: test-final-pose/2/frame_Test_705.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_460.mp4_9_keypoints.json
#   inflating: test-final-pose/2/frame_Test_621.mp4_13_keypoints.json
#   inflating: test-final-pose/2/frame_Test_735.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_187.mp4_11_keypoints.json
#   inflating: test-final-pose/2/frame_Test_116.mp4_10_keypoints.json
#   inflating: test-final-pose/2/frame_Test_266.mp4_1_keypoints.json
#   inflating: test-final-pose/2/frame_Test_717.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_713.mp4_13_keypoints.json
#   inflating: test-final-pose/2/frame_Test_576.mp4_9_keypoints.json
#   inflating: test-final-pose/2/frame_Test_719.mp4_8_keypoints.json
#   inflating: test-final-pose/2/frame_Test_344.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_143.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_21.mp4_11_keypoints.json
#   inflating: test-final-pose/2/frame_Test_265.mp4_3_keypoints.json
#   inflating: test-final-pose/2/frame_Test_385.mp4_1_keypoints.json
#   inflating: test-final-pose/2/frame_Test_701.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_63.mp4_0_keypoints.json
#   inflating: test-final-pose/2/frame_Test_222.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_538.mp4_10_keypoints.json
#   inflating: test-final-pose/2/frame_Test_380.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_735.mp4_10_keypoints.json
#   inflating: test-final-pose/2/frame_Test_116.mp4_0_keypoints.json
#   inflating: test-final-pose/2/frame_Test_311.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_423.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_603.mp4_0_keypoints.json
#   inflating: test-final-pose/2/frame_Test_577.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_252.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_249.mp4_7_keypoints.json
#   inflating: test-final-pose/2/frame_Test_611.mp4_10_keypoints.json
#   inflating: test-final-pose/2/frame_Test_246.mp4_10_keypoints.json
#   inflating: test-final-pose/2/frame_Test_645.mp4_11_keypoints.json
#   inflating: test-final-pose/2/frame_Test_173.mp4_3_keypoints.json
#   inflating: test-final-pose/2/frame_Test_15.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_33.mp4_12_keypoints.json
#   inflating: test-final-pose/2/frame_Test_252.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_390.mp4_14_keypoints.json
#   inflating: test-final-pose/2/frame_Test_236.mp4_12_keypoints.json
#   inflating: test-final-pose/2/frame_Test_535.mp4_12_keypoints.json
#   inflating: test-final-pose/2/frame_Test_630.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_540.mp4_0_keypoints.json
#   inflating: test-final-pose/2/frame_Test_240.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_650.mp4_12_keypoints.json
#   inflating: test-final-pose/2/frame_Test_1.mp4_13_keypoints.json
#   inflating: test-final-pose/2/frame_Test_351.mp4_9_keypoints.json
#   inflating: test-final-pose/2/frame_Test_482.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_705.mp4_11_keypoints.json
#   inflating: test-final-pose/2/frame_Test_33.mp4_2_keypoints.json
#   inflating: test-final-pose/2/frame_Test_711.mp4_14_keypoints.json
#   inflating: test-final-pose/2/frame_Test_415.mp4_3_keypoints.json
#   inflating: test-final-pose/2/frame_Test_527.mp4_1_keypoints.json
#   inflating: test-final-pose/2/frame_Test_474.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_1.mp4_14_keypoints.json
#   inflating: test-final-pose/2/frame_Test_662.mp4_14_keypoints.json
#   inflating: test-final-pose/2/frame_Test_192.mp4_1_keypoints.json
#   inflating: test-final-pose/2/frame_Test_735.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_76.mp4_6_keypoints.json
#   inflating: test-final-pose/2/frame_Test_419.mp4_11_keypoints.json
#   inflating: test-final-pose/2/frame_Test_137.mp4_0_keypoints.json
#   inflating: test-final-pose/2/frame_Test_573.mp4_4_keypoints.json
#   inflating: test-final-pose/2/frame_Test_224.mp4_4_keypoints.json
#   inflating: test-final-pose/2/frame_Test_52.mp4_4_keypoints.json
#   inflating: test-final-pose/2/frame_Test_150.mp4_5_keypoints.json
#   inflating: test-final-pose/2/frame_Test_231.mp4_4_keypoints.json
#   inflating: test-final-pose/2/frame_Test_432.mp4_7_keypoints.json
# Archive:  test-final-fer.zip
#   inflating: test-final-fer/faces-fer-X.npy
#   inflating: test-final-fer/faces-fer-Y.npy

# %%
# !ls |head
# Out:
# drive
# sample_data
# test-final-audio
# test-final-audio.zip
# test-final-faces
# test-final-faces.zip
# test-final-fer
# test-final-fer.zip
# test-final-frames
# test-final-frames.zip

# %% [markdown]
# ### Run Classifiers

# %%
# %tensorflow_version 2.x

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.2.0

# %%
# !pwd
# Out:
# /content

# %%
import urllib
from getpass import getpass
import os
user = input('User name: ')
password = getpass('Password: ')
password = urllib.parse.quote(password) # your password is converted into url format

cmd_string = 'git clone https://{0}:{1}@github.com/kevincong95/cs231n-emotiw.git'.format(user, password)

os.system(cmd_string)
cmd_string, password = "", "" # removing the password from the variable
# Out:
# User name: tbj128
# Password: ··········

# %%
# !mv test-* cs231n-emotiw
# !mv Test* cs231n-emotiw

# %%
# !pwd
# Out:
# /content

# %%
import os
os.chdir('/content/cs231n-emotiw')
# !pwd
# Out:
# /content/cs231n-emotiw

# %%
# !pip install pytorch-transformers
# Out:
# Collecting pytorch-transformers
#   Downloading https://files.pythonhosted.org/packages/a3/b7/d3d18008a67e0b968d1ab93ad444fc05699403fa662f634b2f2c318a508b/pytorch_transformers-1.2.0-py3-none-any.whl (176kB)
#      |████████████████████████████████| 184kB 2.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pytorch-transformers) (1.18.5)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/d4/a4/d0a884c4300004a78cca907a6ff9a5e9fe4f090f5d95ab341c53d28cbc58/sentencepiece-0.1.91-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 7.1MB/s
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from pytorch-transformers) (1.14.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from pytorch-transformers) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 17.0MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from pytorch-transformers) (2019.12.20)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from pytorch-transformers) (1.5.1+cu101)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from pytorch-transformers) (2.23.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->pytorch-transformers) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->pytorch-transformers) (0.10.0)
# Requirement already satisfied: botocore<1.18.0,>=1.17.5 in /usr/local/lib/python3.6/dist-packages (from boto3->pytorch-transformers) (1.17.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->pytorch-transformers) (1.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->pytorch-transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->pytorch-transformers) (0.15.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.0->pytorch-transformers) (0.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-transformers) (2020.4.5.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-transformers) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->pytorch-transformers) (3.0.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.5->boto3->pytorch-transformers) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.5->boto3->pytorch-transformers) (0.15.2)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=18888c9229e759abdcc37932bcc69b3513a1e9d694aa55e2d3e3c39337442890
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sentencepiece, sacremoses, pytorch-transformers
# Successfully installed pytorch-transformers-1.2.0 sacremoses-0.0.43 sentencepiece-0.1.91

# %%
# Create the concatenated input layer to feed into FC

from src.classifiers.audio_classifier import AudioClassifier
from src.classifiers.frames_classifier import FramesClassifier
from src.classifiers.pose_classifier import PoseClassifier
from src.classifiers.face_classifier import FaceClassifier
from src.classifiers.image_captioning_classifier import ImageCaptioningClassifier, FineTuningConfig
from src.classifiers.utils import get_num_samples
import numpy as np

def run_classifier(layers_to_extract, audio_folder='train-final-audio', frames_folder='train-final-frames', pose_folder='train-final-pose', face_folder='train-final-fer', image_caption_pkl="train-final-captions.pkl", image_caption_prefix="train_", labels_file="Train_labels.txt"):
    audio_classifier = AudioClassifier(audio_folder, model_location='https://storage.googleapis.com/cs231n-emotiw/models/openl3-cnn-lstm-tuned-lr.h5', is_test=False)
    frames_classifier = FramesClassifier(frames_folder, model_location='https://storage.googleapis.com/cs231n-emotiw/models/scene-classifier-resnet-lstm-x3.h5', is_test=False)
    frames_classifier_vgg = FramesClassifier(frames_folder, location_prefix="vgg", model_location='https://storage.googleapis.com/cs231n-emotiw/models/vgg19-lstm-cp-0003.h5', is_test=False, batch_size=4)
    pose_classifier = PoseClassifier(pose_folder, model_location='https://storage.googleapis.com/cs231n-emotiw/models/pose-classifier-64lstm-0.01reg.h5', is_test=False)
    face_classifier = FaceClassifier(face_folder, model_location='/content/drive/My Drive/cs231n-project/models/face-classifier-playground/cp-0001.h5', is_test=False)
    image_captioning_classifier = ImageCaptioningClassifier(image_caption_pkl, image_caption_prefix, model_metadata_location="https://storage.googleapis.com/cs231n-emotiw/models/sentiment-transformer-16.metadata.bin", model_location='https://storage.googleapis.com/cs231n-emotiw/models/sentiment-transformer_sentiment-transformer_756.pth', is_test=False)
    
    # classifiers = [audio_classifier, frames_classifier, pose_classifier] # face_classifier]
    classifiers = [audio_classifier, frames_classifier, frames_classifier_vgg, pose_classifier, face_classifier, image_captioning_classifier]
    # classifiers = [frames_classifier_vgg]
    
    sample_to_true_label = {}
    with open(labels_file) as f:
        l = 0
        for line in f:
            if l == 0:
                # Skip headers
                l += 1
                continue
            line_arr = line.split(" ")
            sample_to_true_label[line_arr[0].strip()] = int(line_arr[1].strip()) - 1 # subtract one to make labels from 0 to 2
            l += 1

    classifier_outputs = []
    classifier_samples = []
    classifier_dim_sizes = []
    output_dim_size = 0
    num_samples = 0
    sample_to_row = {}

    for i, classifier in enumerate(classifiers):
        output, samples = classifier.predict(layers_to_extract[i])
        output_dim_size += output.shape[1]
        classifier_dim_sizes.append(output.shape[1])
        num_samples = len(samples)
        classifier_outputs.append(output)
        classifier_samples.append(samples)


    X_train = np.zeros(shape=(num_samples, output_dim_size))
    y_train = []

    print(f"Number of samples: {num_samples}")
    print(f"Dim shapes: ")
    print(classifier_dim_sizes)

    for i, sample in enumerate(classifier_samples[0]):
        sample_to_row[sample] = i
        y_train.append(sample_to_true_label[sample])

    last_classifier_index = 0
    for c, output in enumerate(classifier_outputs):
        samples = classifier_samples[c]
        print(len(output))
        for i, row in enumerate(output):
            sample = samples[i]
            X_train[sample_to_row[sample], last_classifier_index:last_classifier_index+classifier_dim_sizes[c]] += row
        last_classifier_index += classifier_dim_sizes[c]

    return X_train, tf.keras.utils.to_categorical(y_train, num_classes=3)
# Out:
# 100%|██████████| 213450/213450 [00:00<00:00, 289696.28B/s]

# %%
import tensorflow as tf
# For each classifier, extract the specific desired layer 
# (refer to the model summary for the layer names)

layers_to_extract = [
    "dense", # Audio
    "concatenate_5", # ResNet
    "global_average_pooling3d_1", # VGG
    "bidirectional_1", # Pose
    "dense_27", # FER
    "classification_head" # Image Caption
]

prefix = "final"
X_test, y_test = run_classifier(layers_to_extract, audio_folder=f"test-{prefix}-audio", frames_folder=f"test-{prefix}-frames", pose_folder=f"test-{prefix}-pose" , face_folder=f"test-{prefix}-fer" , image_caption_pkl="test-final-captions.pkl", image_caption_prefix="test_", labels_file="Test_labels.txt")

print(X_test.shape)
print(y_test.shape)
# Out:
# AudioClassifier created with audio_folder = test-final-audio , is_test = False , model_location = https://storage.googleapis.com/cs231n-emotiw/models/openl3-cnn-lstm-tuned-lr.h5
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# FramesClassifier created with frames_folder = test-final-frames , is_test = False , model_location = https://storage.googleapis.com/cs231n-emotiw/models/scene-classifier-resnet-lstm-x3.h5
# FramesClassifier created with frames_folder = test-final-frames , is_test = False , model_location = https://storage.googleapis.com/cs231n-emotiw/models/vgg19-lstm-cp-0003.h5
# PoseClassifier created with pose_folder = test-final-pose , is_test = False , model_location = https://storage.googleapis.com/cs231n-emotiw/models/pose-classifier-64lstm-0.01reg.h5
# load data
# FacesClassifier created with face_folder = test-final-fer , is_test = False , model_location = /content/drive/My Drive/cs231n-project/models/face-classifier-playground/cp-0001.h5
# ImageCaptioningClassifier created with caption_pkl = test-final-captions.pkl , is_test = False , model_location = https://storage.googleapis.com/cs231n-emotiw/models/sentiment-transformer_sentiment-transformer_756.pth
# Skipping unzipping files as input is a folder
# Customizing model by returning layer dense
# Skipping unzipping files as input is a folder
# Found 756 frames belonging to 756 videos belonging to 3 classes.
# Min frames determined to be 11
# Customizing model by returning layer concatenate_5
# Skipping unzipping files as input is a folder
# Found 756 frames belonging to 756 videos belonging to 3 classes.
# Min frames determined to be 11
# Customizing model by returning layer global_average_pooling3d_1
# Skipping unzipping files as input is a folder
# ['1', '2', '3']
# Found 756 frames belonging to 756 videos belonging to 3 classes.
# Min frames determined to be 11
# Customizing model by returning layer bidirectional_1
# /content/cs231n-emotiw/src/generators/pose_generator.py:135: RuntimeWarning: invalid value encountered in double_scalars
#   x_new.append((lx[i] - origin_x) / len_x)
# /content/cs231n-emotiw/src/generators/pose_generator.py:136: RuntimeWarning: invalid value encountered in double_scalars
#   x_new.append((ly[i] - origin_y) / len_y)
# Customizing model by returning layer dense_27
# HBox(children=(FloatProgress(value=0.0, description='Processing 756 examples on 2 cores', max=756.0, style=Pro…
# Number of samples: 756
# Dim shapes:
# [32, 30, 40, 128, 8, 16]
# 756
# 756
# 756
# 756
# 756
# 756
# (756, 254)
# (756, 3)

# %%
# !rm -rf ensemble-scene-scene-pose-audio-face-caption-v1-test
# !mkdir ensemble-scene-scene-pose-audio-face-caption-v1-test
np.save("ensemble-scene-scene-pose-audio-face-caption-v1-test/X_test.npy", X_test)
np.save("ensemble-scene-scene-pose-audio-face-caption-v1-test/y_test.npy", y_test)
# !zip -r ensemble-scene-scene-pose-audio-face-caption-v1-test.zip ensemble-scene-scene-pose-audio-face-caption-v1-test
# !cp ensemble-scene-scene-pose-audio-face-caption-v1-test.zip ../drive/'My Drive'/cs231n-project/datasets/emotiw
# Out:
#   adding: ensemble-scene-scene-pose-audio-face-caption-v1-test/ (stored 0%)
#   adding: ensemble-scene-scene-pose-audio-face-caption-v1-test/X_test.npy (deflated 48%)
#   adding: ensemble-scene-scene-pose-audio-face-caption-v1-test/y_test.npy (deflated 94%)

# %%
# !ls "../drive/My Drive/cs231n-project/models/ensemble-scene-scene-pose-audio-face-caption-v1/"
# Out:
# cp-0034.h5

# %%
import tensorflow as tf

model = tf.keras.models.load_model('/content/drive/My Drive/cs231n-project/models/ensemble-scene-scene-pose-audio-face-caption-v1/cp-0034.h5')

# %%
#
# CONFIGURATION
#
# Define any constants for the model here
#

from pathlib import Path
import tensorflow as tf
import matplotlib.pyplot as plt

sizes = [32, 30, 40, 128, 8, 16]

# # UNCOMMENT IF EXCLUDING FER, IMAGE CAP, AND VGG
# mask = []
# for x in range(sum(sizes)):
#     if x >= 32 and x < 62:
#         mask.append(False)
#     elif x < 230:
#         mask.append(True)
#     else:
#         mask.append(False)

# # UNCOMMENT IF EXCLUDING FER, IMAGE CAP, POSE, AND RESNET
# mask = []
# for x in range(sum(sizes)):
#     if x >= 62 and x < 102:
#         mask.append(False)
#     elif x < 62:
#         mask.append(True)
#     else:
#         mask.append(False)
  
# # UNCOMMENT IF EXCLUDING FER, AND VGG
# mask = []
# for x in range(sum(sizes)):
#     if x >= 30 and x < 62:
#         mask.append(False)
#     elif x < 230:
#         mask.append(True)
#     elif x >= 238:
#         mask.append(True)
#     else:
#         mask.append(False)

# UNCOMMENT IF EXCLUDING FER, AND RESNET [best]
mask = []
for x in range(sum(sizes)):
    if x >= 62 and x < 102:
        mask.append(False)
    elif x < 230:
        mask.append(True)
    elif x >= 238:
        mask.append(True)
    else:
        mask.append(False)

# # UNCOMMENT IF EXCLUDING FER, IMAGE CAP, AND RESNET [best]
# mask = []
# for x in range(sum(sizes)):
#     if x >= 62 and x < 102:
#         mask.append(False)
#     elif x < 230:
#         mask.append(True)
#     else:
#         mask.append(False)

# UNCOMMENT IF EXCLUDING FER AND IMAGE CAP
# mask = []
# for x in range(sum(sizes)):
#     if x < 230:
#         mask.append(True)
#     else:
#         mask.append(False)

# # UNCOMMENT IF EXCLUDING FER
# mask = []
# for x in range(sum(sizes)):
#     if x < 230:
#         mask.append(True)
#     elif x >= 238:
#         mask.append(True)
#     else:
#         mask.append(False)


import pickle
history = model.evaluate(
          x=X_test[:, mask],
          y=y_test
)
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0889 - accuracy: 0.5992

# %%
import pickle
predictions = model.predict(
          x=X_test[:, mask]
)

# %%
len(y_test)
# Out:
# 756

# %%
len(predictions)
# Out:
# 756

# %%
y_true_final = np.argmax(y_test, axis=1)
y_pred_final = np.argmax(predictions, axis=1)

# %%
from sklearn import metrics 
import pandas as pd
import seaborn as sn
cm=metrics.confusion_matrix(y_true_final,y_pred_final)
import matplotlib.pyplot as plt

classes=['Pos' , 'Neu' , 'Neg']
con_mat = tensorflow.math.confusion_matrix(labels=y_true_final, predictions=y_pred_final).numpy()
con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)
con_mat_df = pd.DataFrame(con_mat_norm,
                  index = classes, 
                  columns = classes)

figure = plt.figure(figsize=(11, 9))
plt.title("FC Voting Confusion Matrix with Scene & Audio")
sn.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)


accuracy = (y_pred_final == y_true_final).mean()
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.5992063492063492

# %%
y_pred_final
# Out:
# array([1, 0, 0, 0, 2, 0, 0, 1, 1, 2, 1, 0, 1, 0, 1, 0, 2, 2, 2, 1, 1, 2,
#        1, 0, 2, 1, 2, 0, 2, 1, 1, 1, 1, 0, 1, 1, 1, 0, 1, 2, 1, 1, 1, 2,
#        2, 0, 1, 1, 1, 0, 2, 1, 1, 0, 2, 1, 0, 1, 0, 1, 2, 2, 1, 0, 1, 2,
#        0, 0, 1, 0, 2, 0, 0, 2, 2, 0, 0, 1, 0, 0, 0, 1, 2, 0, 1, 1, 0, 0,
#        2, 0, 0, 1, 1, 2, 1, 1, 2, 1, 0, 0, 0, 1, 0, 2, 0, 2, 1, 1, 1, 0,
#        0, 1, 0, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 1, 1, 1, 0, 0,