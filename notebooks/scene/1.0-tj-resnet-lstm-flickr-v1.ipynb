# %% [markdown]
# [✓] Rerun with updated EmotiW dataset
#
# ### ResNet-LSTM
# - ResNet-50 (Flickr-trained)
# - LSTM
#
# Best Model (Val Acc):
#
# Best Model (Val Loss):

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# !cp 'drive/My Drive/cs231n-project/datasets/emotiw/train_frames.tar.gz' .

# %%
# !tar -xzf train_frames.tar.gz

# %%
# !cp 'drive/My Drive/cs231n-project/datasets/emotiw/val_frames.tar.gz' .
# !tar -xzf val_frames.tar.gz

# %%
# !ls 'drive/My Drive/cs231n-project/datasets/emotiw/'
# Out:
#  AutomaticGroupLevelAffectandCohesion.pdf    train-tiny-faces.zip
# 'Copy of Train.zip'			     train-tiny-local.zip
# 'Copy of Val.zip'			     train-tiny-pose.zip
#  fer2013_mini_XCEPTION.119-0.65.hdf5	     train-tiny.zip
#  models					     Train.zip
#  preprocess				     unzip.ipynb
# 'Screen Shot 2020-05-26 at 8.51.22 PM.png'   val
#  test-tiny-local.zip			     val_frames_keypoints_old.tar.gz
#  test-tiny-pose.zip			     val_frames_keypoints.tar.gz
#  test-tiny.zip				     val_frames_old.tar.gz
#  train					     val_frames.tar.gz
#  train_frames_keypoints_old.tar.gz	     Val_labels_old.txt
#  train_frames_keypoints.tar.gz		     Val_labels.txt
#  train_frames_old.tar.gz		     val-tiny
#  train_frames.tar.gz			     val-tiny-audio.zip
#  Train_labels.gdoc			     val-tiny-local.zip
#  Train_labels_old.txt			     val-tiny-pose.zip
#  Train_labels.txt			     val-tiny.zip
#  train-tiny				     Val.zip
#  train-tiny-audio.zip			     VGAF_readme.txt

# %%
# !nvidia-smi
# Out:
# Sun May 31 05:52:14 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np
import random
import cv2
from os import listdir
from os.path import isfile, join

class DataGenerator(tf.keras.utils.Sequence):
    """
    Generates data based on a directory of frames
    """
    def __init__(self, dir, batch_size=32, frames_to_use=-1, shuffle=True):
        self.frames_to_use = frames_to_use
        self.batch_size = batch_size
        self.dir = dir
        self.shuffle = shuffle
        self.classes = self.find_classes()
        self.video_names, self.video_map, self.video_to_class, self.num_samples, self.min_frames = self.find_samples()
        self.on_epoch_end()
        print(f"Found {self.num_samples} frames belonging to {len(self.video_names)} videos belonging to {len(self.classes)} classes.")
        print(f"Min frames determined to be {self.min_frames}")

    def find_classes(self):
        category_folders = [f for f in listdir(self.dir) if not isfile(join(self.dir, f))]
        return sorted(list(set(category_folders)))

    def find_samples(self):
        """
        Returns the following video frame structure:

        {
            "vid1": [
                "frame1.jpg",
                "frame2.jpg",
                ...
            ]
        }

        """
        num_samples = 0
        min_frames = -1
        video_map = {}
        vid_to_cat = {}
        category_folders = [f for f in listdir(self.dir) if not isfile(join(self.dir, f))]
        for category_folder in category_folders:
            cat_path = join(self.dir, category_folder)
            frames = [f for f in listdir(cat_path) if isfile(join(cat_path, f))]
            for frame in frames:
                # frame = frame_101_7.mp4_8.jpg
                frame_arr = frame.split(".mp4_")
                vid_name = frame_arr[0]
                if vid_name not in video_map:
                    video_map[vid_name] = []
                    vid_to_cat[vid_name] = category_folder
                video_map[vid_name].append(frame)
            
            for k in video_map.keys():
                # make sure the frames for each video are in sorted order
                video_map[vid_name] = sorted(video_map[vid_name])
                if min_frames == -1 or len(video_map[vid_name]) < min_frames:
                    min_frames = len(video_map[vid_name])

        return list(video_map.keys()), video_map, vid_to_cat, len(vid_to_cat), min_frames

    def __len__(self):
        """
        Denotes the number of batches per epoch
        """
        return int(np.floor(self.num_samples / self.batch_size))

    def __getitem__(self, index):
        """
        Generate one batch of data
        """
        video_names = self.video_names[index*self.batch_size:(index+1)*self.batch_size]

        # print(f"Working on batch {index} with {len(video_names)} videos")

        num_frames = self.min_frames if self.frames_to_use == -1 else self.frames_to_use
        X = np.zeros((len(video_names), num_frames, IMG_HEIGHT, IMG_WIDTH, 3), dtype=np.uint8)
        y = []
        i = 0
        for vid in video_names:
            # print(vid)
            j = 0
            for frame in self.video_map[vid]:
                # print("   " + frame)
                frame_path = join(join(self.dir, self.video_to_class[vid]), frame)
                img = cv2.imread(frame_path)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                # Assume resized already
                # img = cv2.resize(image, (IMG_WIDTH, IMG_HEIGHT), interpolation = cv2.INTER_CUBIC)
                # print(img[0])
                X[i, j, :, :, :] = img
                j += 1
                if j >= num_frames:
                    break

            y.append(int(self.video_to_class[vid]) - 1)
            # print(f"{vid} - {int(self.video_to_class[vid]) - 1}")
            i += 1
        y = np.array(y)
        return X, tf.keras.utils.to_categorical(y, num_classes=len(self.classes))

    def on_epoch_end(self):
        # print("on_epoch_end")
        if self.shuffle == True:
            np.random.shuffle(self.video_names)

# %%
#
# CONFIGURATION
#
# Define any constants for the model here
#

IMG_WIDTH = 480
IMG_HEIGHT = 320
FRAMES = 12
BATCH_SIZE = 8
BASE_NAME = "resnet50"
MODEL_NAME = "resnet-lstm-flickr"

# %%
train_generator = DataGenerator("train_frames", frames_to_use=FRAMES, batch_size=BATCH_SIZE)
validation_generator = DataGenerator("val_frames", frames_to_use=FRAMES, batch_size=BATCH_SIZE)

X, y = train_generator.__getitem__(0)
# Out:
# Found 2661 frames belonging to 2661 videos belonging to 3 classes.
# Min frames determined to be 15
# Found 766 frames belonging to 766 videos belonging to 3 classes.
# Min frames determined to be 13

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(30,30))
    for n in range(4):
          ax = plt.subplot(5,5,n+1)
          plt.imshow(image_batch[n, 0])
          plt.title(label_batch[n])
          plt.axis('off')
image_batch, label_batch = train_generator.__getitem__(1)
show_batch(image_batch, label_batch)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
def show_frames_batch(image_batch, label_batch):
    plt.figure(figsize=(60,60))
    for n in range(6):
        ax = plt.subplot(1,6,n+1)
        plt.imshow(image_batch[0, n])
        plt.title(label_batch[0])
        plt.axis('off')
image_batch, label_batch = train_generator.__getitem__(0)
show_frames_batch(image_batch, label_batch)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from pathlib import Path

IMG_SHAPE = (IMG_HEIGHT, IMG_WIDTH, 3)

Path(f"drive/My Drive/checkpoints/{MODEL_NAME}").mkdir(parents=True, exist_ok=True)
checkpoint_path = "drive/My Drive/checkpoints/" + MODEL_NAME + "/cp-{epoch:04d}.h5"

# Create a callback that saves the model's weights every 1 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
    period=1)

def create_model(inputs):
    # Extract ResNet part of the model
    base_model = tf.keras.models.load_model(f"drive/My Drive/checkpoints-old/resnet-flickr-r1/fine-tuned-first100frozen.h5").layers[1]
    base_model.trainable = False
    # for layer in base_model.layers[:100]:
    #     layer.trainable = False
    # for layer in base_model.layers[100:]:
    #     layer.trainable = True

    x = tf.keras.layers.TimeDistributed(base_model)(inputs)
    x = tf.keras.layers.ConvLSTM2D(filters=40, kernel_size=(3, 3), padding='same', return_sequences=True)(x)
    x = tf.keras.layers.GlobalAveragePooling3D()(x)
    x = tf.keras.layers.Dense(3, activation='softmax')(x)

    model = tf.keras.Model(inputs=inputs, outputs=x)
    model.compile(optimizer='adam',
                  loss = 'categorical_crossentropy',
                  metrics=['accuracy'])
    return model

def get_base_model(model_name="resnet50"):
    if model_name == 'inception_v3':
        return tf.keras.applications.InceptionV3(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    elif model_name == 'xception':
        return tf.keras.applications.Xception(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    elif model_name == 'vgg16':
        return tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    elif model_name == 'vgg19':
        return tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    elif model_name == 'resnet50':
        return tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    else:
        raise ValueError(f"Cannot find base model {model_name}")

inputs = tf.keras.Input(shape=(FRAMES, IMG_HEIGHT, IMG_WIDTH, 3))
model = create_model(inputs)
model.summary()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 12, 320, 480, 3)] 0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 12, 10, 15, 2048)  23587712
# _________________________________________________________________
# conv_lst_m2d (ConvLSTM2D)    (None, 12, 10, 15, 40)    3006880
# _________________________________________________________________
# global_average_pooling3d (Gl (None, 40)                0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 123
# =================================================================
# Total params: 26,594,715
# Trainable params: 3,007,003
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
initial_epochs = 10

# Try evaluating the model for a few rounds
# history = model.fit(train_generator, epochs=1)
loss0, accuracy0 = model.evaluate(validation_generator, steps = 3)
# Out:
# 3/3 [==============================] - 1s 295ms/step - loss: 1.0821 - accuracy: 0.4583

# %%
validation_generator.batch_size
# Out:
# 8

# %%
import pickle
history = model.fit(
          train_generator,
          epochs=initial_epochs,
          callbacks=[cp_callback],
          validation_data=validation_generator
)

with open(f"drive/My Drive/checkpoints/{MODEL_NAME}/history.pkl", 'wb') as handle:
    pickle.dump(history.history, handle)
# Out:
# Epoch 1/10
# 332/332 [==============================] - ETA: 0s - loss: 1.1181 - accuracy: 0.4575
# Epoch 00001: val_loss improved from inf to 1.06105, saving model to drive/My Drive/checkpoints/resnet-lstm-flickr/cp-0001.h5
# 332/332 [==============================] - 233s 701ms/step - loss: 1.1181 - accuracy: 0.4575 - val_loss: 1.0611 - val_accuracy: 0.4526
# Epoch 2/10
# 332/332 [==============================] - ETA: 0s - loss: 0.9804 - accuracy: 0.5192
# Epoch 00002: val_loss did not improve from 1.06105
# 332/332 [==============================] - 214s 644ms/step - loss: 0.9804 - accuracy: 0.5192 - val_loss: 1.0769 - val_accuracy: 0.4382
# Epoch 3/10
# 332/332 [==============================] - ETA: 0s - loss: 0.9202 - accuracy: 0.5478
# Epoch 00003: val_loss improved from 1.06105 to 1.02064, saving model to drive/My Drive/checkpoints/resnet-lstm-flickr/cp-0003.h5
# 332/332 [==============================] - 207s 623ms/step - loss: 0.9202 - accuracy: 0.5478 - val_loss: 1.0206 - val_accuracy: 0.4250
# Epoch 4/10
# 332/332 [==============================] - ETA: 0s - loss: 0.8846 - accuracy: 0.5809
# Epoch 00004: val_loss improved from 1.02064 to 1.00720, saving model to drive/My Drive/checkpoints/resnet-lstm-flickr/cp-0004.h5
# 332/332 [==============================] - 206s 622ms/step - loss: 0.8846 - accuracy: 0.5809 - val_loss: 1.0072 - val_accuracy: 0.4487
# Epoch 5/10
# 332/332 [==============================] - ETA: 0s - loss: 0.8532 - accuracy: 0.6081
# Epoch 00005: val_loss did not improve from 1.00720
# 332/332 [==============================] - 206s 621ms/step - loss: 0.8532 - accuracy: 0.6081 - val_loss: 1.0491 - val_accuracy: 0.4803
# Epoch 6/10
# 332/332 [==============================] - ETA: 0s - loss: 0.8129 - accuracy: 0.6299
# Epoch 00006: val_loss did not improve from 1.00720
# 332/332 [==============================] - 206s 621ms/step - loss: 0.8129 - accuracy: 0.6299 - val_loss: 1.0383 - val_accuracy: 0.4408
# Epoch 7/10
# 332/332 [==============================] - ETA: 0s - loss: 0.8019 - accuracy: 0.6303
# Epoch 00007: val_loss did not improve from 1.00720
# 332/332 [==============================] - 206s 621ms/step - loss: 0.8019 - accuracy: 0.6303 - val_loss: 1.1158 - val_accuracy: 0.4461
# Epoch 8/10
# 332/332 [==============================] - ETA: 0s - loss: 0.7636 - accuracy: 0.6702
# Epoch 00008: val_loss improved from 1.00720 to 0.99915, saving model to drive/My Drive/checkpoints/resnet-lstm-flickr/cp-0008.h5
# 332/332 [==============================] - 206s 621ms/step - loss: 0.7636 - accuracy: 0.6702 - val_loss: 0.9991 - val_accuracy: 0.4803
# Epoch 9/10
# 332/332 [==============================] - ETA: 0s - loss: 0.7462 - accuracy: 0.6717
# Epoch 00009: val_loss improved from 0.99915 to 0.98255, saving model to drive/My Drive/checkpoints/resnet-lstm-flickr/cp-0009.h5
# 332/332 [==============================] - 206s 621ms/step - loss: 0.7462 - accuracy: 0.6717 - val_loss: 0.9825 - val_accuracy: 0.5145
# Epoch 10/10
# 332/332 [==============================] - ETA: 0s - loss: 0.7222 - accuracy: 0.6905
# Epoch 00010: val_loss did not improve from 0.98255
# 332/332 [==============================] - 205s 619ms/step - loss: 0.7222 - accuracy: 0.6905 - val_loss: 1.0237 - val_accuracy: 0.4947

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']


plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
history = model.fit(
          train_generator,
          initial_epoch=10,
          epochs=15,
          callbacks=[cp_callback],
          validation_data=validation_generator
)
# Out:
# Epoch 11/15
# 332/332 [==============================] - ETA: 0s - loss: 0.7045 - accuracy: 0.7022
# Epoch 00011: val_loss did not improve from 0.98255
# 332/332 [==============================] - 206s 621ms/step - loss: 0.7045 - accuracy: 0.7022 - val_loss: 1.0313 - val_accuracy: 0.4645
# Epoch 12/15
# 332/332 [==============================] - ETA: 0s - loss: 0.6702 - accuracy: 0.7203
# Epoch 00012: val_loss did not improve from 0.98255
# 332/332 [==============================] - 206s 621ms/step - loss: 0.6702 - accuracy: 0.7203 - val_loss: 1.1004 - val_accuracy: 0.4592
# Epoch 13/15
# 332/332 [==============================] - ETA: 0s - loss: 0.6541 - accuracy: 0.7225
# Epoch 00013: val_loss did not improve from 0.98255
# 332/332 [==============================] - 206s 620ms/step - loss: 0.6541 - accuracy: 0.7225 - val_loss: 1.0795 - val_accuracy: 0.4355
# Epoch 14/15
# 332/332 [==============================] - ETA: 0s - loss: 0.6438 - accuracy: 0.7282
# Epoch 00014: val_loss did not improve from 0.98255
# 332/332 [==============================] - 206s 620ms/step - loss: 0.6438 - accuracy: 0.7282 - val_loss: 0.9883 - val_accuracy: 0.5421
# Epoch 15/15
# 332/332 [==============================] - ETA: 0s - loss: 0.6240 - accuracy: 0.7323
# Epoch 00015: val_loss did not improve from 0.98255
# 332/332 [==============================] - 206s 620ms/step - loss: 0.6240 - accuracy: 0.7323 - val_loss: 1.0426 - val_accuracy: 0.4829
